# %%
import pandas as pd
from sqlalchemy import create_engine

# 1. CSV 파일 읽기
df = pd.read_csv('../pss/data/서울_구별.csv')

# 2. DB 연결 설정 (예: MySQL)
# 'mysql+pymysql://사용자명:비밀번호@호스트:포트/DB이름'
engine = create_engine('mysql://root:12341234@127.0.0.1:3306/pj2601') 


# 3. DB로 전송
df.to_sql('district', con=engine, if_exists='append', index=False)
# Out:
# 24

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd
from sqlalchemy import create_engine

# 1. CSV 파일 읽기
df = pd.read_csv('C:/Users/User/Documents/MBCAcademy_PJ1/data/pj2601_연도별등록합계.csv')

# 2. DB 연결 설정 (예: MySQL)
# 'mysql+pymysql://사용자명:비밀번호@호스트:포트/DB이름'
engine = create_engine('mysql://root:12341234@127.0.0.1:3306/pj2601') 


# 3. DB로 전송
df.to_sql('year_reg', con=engine, if_exists='append', index=False)
# Out:
# 3

# %%
# 1. CSV 파일 읽기
df = pd.read_csv('../pss/data/01_kangnam.csv')

# 2. DB 연결 설정 (예: MySQL)
# 'mysql+pymysql://사용자명:비밀번호@호스트:포트/DB이름'
engine = create_engine('mysql://root:12341234@127.0.0.1:3306/pj2601') 


# 3. DB로 전송
df.to_sql('01_kangnam', con=engine, if_exists='append', index=False)
# Out:
# 49

# %%
# 1. CSV 파일 읽기
df = pd.read_csv('../pss/data/02_kangdong.csv')

# 2. DB 연결 설정 (예: MySQL)
# 'mysql+pymysql://사용자명:비밀번호@호스트:포트/DB이름'
engine = create_engine('mysql://root:12341234@127.0.0.1:3306/pj2601') 


# 3. DB로 전송
df.to_sql('02_kangdong', con=engine, if_exists='append', index=False)
# Out:
# 49

# %%
df = pd.read_csv('../pss/data/03_kangbuk.csv')

# 2. DB 연결 설정 (예: MySQL)
# 'mysql+pymysql://사용자명:비밀번호@호스트:포트/DB이름'
engine = create_engine('mysql://root:12341234@127.0.0.1:3306/pj2601') 


# 3. DB로 전송
df.to_sql('03_kangbuk', con=engine, if_exists='append', index=False)
# Out:
# 49

# %%
df = pd.read_csv('../pss/data/04_kangseo.csv')

# 2. DB 연결 설정 (예: MySQL)
# 'mysql+pymysql://사용자명:비밀번호@호스트:포트/DB이름'
engine = create_engine('mysql://root:12341234@127.0.0.1:3306/pj2601') 


# 3. DB로 전송
df.to_sql('04_kangseo', con=engine, if_exists='append', index=False)
# Out:
# 49

# %%
df = pd.read_csv('../pss/data/05_kwanak.csv')

# 2. DB 연결 설정 (예: MySQL)
# 'mysql+pymysql://사용자명:비밀번호@호스트:포트/DB이름'
engine = create_engine('mysql://root:12341234@127.0.0.1:3306/pj2601') 


# 3. DB로 전송
df.to_sql('05_kwanak', con=engine, if_exists='append', index=False)
# Out:
# 49

# %%
df = pd.read_csv('../pss/data/06_kwangjin.csv')

# 3. DB로 전송
df.to_sql('06_kwangjin', con=engine, if_exists='append', index=False)
# Out:
# 49

# %%
df = pd.read_csv('../pss/data/07_guro.csv')

# 3. DB로 전송
df.to_sql('07_guro', con=engine, if_exists='append', index=False)
# Out:
# 49

# %%
df = pd.read_csv('../pss/data/08_keumcheon.csv')

# 3. DB로 전송
df.to_sql('08_keumcheon', con=engine, if_exists='append', index=False)
# Out:
# 49

# %%
df = pd.read_csv('../pss/data/09_nowon.csv')

# 3. DB로 전송
df.to_sql('09_nowon', con=engine, if_exists='append', index=False)
# Out:
# 49

# %%
df = pd.read_csv('../pss/data/10_dobong.csv')

# 3. DB로 전송
df.to_sql('10_dobong', con=engine, if_exists='append', index=False)
# Out:
# 49

# %%
df = pd.read_csv('../pss/data/11_dongdaemun.csv')
df.to_sql('11_dongdaemun', con=engine, if_exists='append', index=False)

df1 = pd.read_csv('../pss/data/12_dongjak.csv')
df1.to_sql('12_dongjak', con=engine, if_exists='append', index=False)

df2 = pd.read_csv('../pss/data/13_mapo.csv')
df2.to_sql('13_mapo', con=engine, if_exists='append', index=False)

df3 = pd.read_csv('../pss/data/14_seodaemun.csv')
df3.to_sql('14_seodaemun', con=engine, if_exists='append', index=False)

df4 = pd.read_csv('../pss/data/15_seocho.csv')
df4.to_sql('15_seocho', con=engine, if_exists='append', index=False)

df5 = pd.read_csv('../pss/data/16_seongdong.csv')
df5.to_sql('16_seongdong', con=engine, if_exists='append', index=False)

df6 = pd.read_csv('../pss/data/17_seongbuk.csv')
df6.to_sql('17_seongbuk', con=engine, if_exists='append', index=False)

df7 = pd.read_csv('../pss/data/18_songpa.csv')
df7.to_sql('18_songpa', con=engine, if_exists='append', index=False)

df8 = pd.read_csv('../pss/data/19_yangcheon.csv')
df8.to_sql('19_yangcheon', con=engine, if_exists='append', index=False)

df9 = pd.read_csv('../pss/data/20_youngdeungpo.csv')
df9.to_sql('20_youngdeungpo', con=engine, if_exists='append', index=False)

df10 = pd.read_csv('../pss/data/21_yongsan.csv')
df10.to_sql('21_yongsan', con=engine, if_exists='append', index=False)

df11 = pd.read_csv('../pss/data/22_eunpyoung.csv')
df11.to_sql('22_eunpyoung', con=engine, if_exists='append', index=False)

df12 = pd.read_csv('../pss/data/23_jongno.csv')
df12.to_sql('23_jongno', con=engine, if_exists='append', index=False)

df13 = pd.read_csv('../pss/data/24_joong.csv')
df13.to_sql('24_joong', con=engine, if_exists='append', index=False)

df14 = pd.read_csv('../pss/data/25_joongrang.csv')
df14.to_sql('25_joongrang', con=engine, if_exists='append', index=False)
# Out:
# 49

# %%
import pandas as pd
from sqlalchemy import create_engine

df = pd.read_csv('../pss/data/교통량증가.csv')
# 2. DB 연결 설정 (예: MySQL)
# 'mysql+pymysql://사용자명:비밀번호@호스트:포트/DB이름'
engine = create_engine('mysql://root:12341234@127.0.0.1:3306/pj2601') 
# 3. DB로 전송
df.to_sql('traffic_add', con=engine, if_exists='append', index=False)
# Out:
# 6
