# %%
import pandas as pd
df=pd.read_csv('./df2.csv')

# %%
df
# Out:
#     자치구별    연도  발생건수 (건)  자동차 1만대당 발생건수 (건)  사망자수 (명)  인구 10만명당 사망자수 (명)  \
# 0    종로구  2020       903              142.3         5                3.1
# 1     중구  2020       955              145.7         6                4.5
# 2    용산구  2020       890               92.9        12                4.9
# 3    성동구  2020      1119               88.7         9                3.0
# 4    광진구  2020       869               73.9         4                1.1
# ..   ...   ...       ...                ...       ...                ...
# 120  관악구  2024      1254               90.4        13                2.6
# 121  서초구  2024      2027              106.6        17                4.1
# 122  강남구  2024      3754              138.8        11                2.0
# 123  송파구  2024      2500               95.5        20                3.0
# 124  강동구  2024      1428               79.9         9                1.9
#
#      부상자수 (명)  인구 10만명당 부상자수 (명)   사고당 사망률   사고당 부상률 CCTV설치대수
# ...
